# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Plotting (Need)</span></div>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Some data for plotting
x = [0, 1, 2, 3, 4, 5, 6] # list 1
y_1 = [0, 2, 4, 6, 8, 10, 12] # list 2
y_2 = [0, 3, 6, 9, 12, 15, 18] # list 3

# Let's start plotting
plt.plot(x, y_1, label='Y values',
         color='red', linestyle='dashed') #color can be c , linestyle can be ls
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=.25)
plt.legend(loc='upper left')
plt.savefig("xvsy.jpg")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Some data for plotting
x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]

# Let's start plotting
plt.plot(x, y_1)

# %%
# !dir
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 300A-9C4A
#
#  Directory of C:\Users\keirh\Documents\learning-portfolio-2025-january-keirlhjk\7.1_plotting
#
# 16/02/2025  09:19 pm    <DIR>          .
# 04/02/2025  09:07 pm    <DIR>          ..
# 16/02/2025  08:58 pm    <DIR>          .ipynb_checkpoints
# 04/02/2025  07:16 pm             4,087 plotting_(good).ipynb
# 16/02/2025  09:17 pm            55,139 plotting_(need).ipynb
# 16/02/2025  09:19 pm            22,079 xvsy.jpg
#                3 File(s)         81,305 bytes
#                3 Dir(s)  295,321,116,672 bytes free

# %%
# Some data for plotting
x = [0, 1, 2, 3, 4, 5, 6] # list 1
y_1 = [0, 2, 4, 6, 8, 10, 12] # list 2
y_2 = [0, 3, 6, 9, 12, 15, 18] # list 3

# Let's start plotting
plt.plot(x, y_1, label='Y values', ls='dashed',
         color='red') #color can be c , linestyle can be ls
plt.scatter(x, y_2, label='Y values',
         color='b') #color can be c , linestyle can be ls
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=.25) # alpha controls opacity/transparency of grid
plt.legend(loc='upper right') # loc is location
plt.savefig("xvsy.jpg") # save as pdf, png, jpg etc. Use !dir to check
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Use Generative AI to aid in plotting, saves time.

# %%
# Some data for plotting
x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]
y_3 = [0, 4, 8, 12, 16, 20, 24]
x_error, y_error = .1, 0.75

# Lets start plotting
plt.plot(x, y_1, label='Y1 values', color='red', linestyle='dashed',)
plt.plot(x, y_2, label='Y2 values', color='blue', )
plt.errorbar(x, y_3, xerr=x_error, yerr=y_error,
             label='Y3 with errors', color='green') # constant error of .1 for x and .75 for y (assigned).
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=.25)
plt.legend(loc='upper left')

# %%
x = np.array([0, 1, 2, 3, 4, 5, 6])

x2 = x**2                  # The math stuff
sin_x = np.sin(x)

#plt.plot(x, x2, label='x^2',
 #        color='red', linestyle='dashed', )
plt.plot(x, sin_x, label='sin(x)',
         color='blue')
plt.legend()   

# Graph is weird bc we are only calculating sinx at 7 values. Because its discreet, doesnt work as well.

# %%
# x = np.array([0, 1, 2, 3, 4, 5, 6])
x = np.linspace(0, 2*np.pi, 1000) # created a numpy array that goes from 0 to 2pi, and it has 1000 points in the middle. 
x2 = x**2                  
sin_x = np.sin(x) #sinx is calculated at 1000 points

#plt.plot(x, x2, label='x^2',
 #        color='red', linestyle='dashed', )
plt.plot(x, sin_x, label='sin(x)',
         color='blue')
plt.legend()

# %%
len(x)
# Out:
# 1000

# %%
print(x[0], x[-1])
# Out:
# 0.0 6.283185307179586

# %%
type(x)
# Out:
# numpy.ndarray

# %%
# x = np.array([0, 1, 2, 3, 4, 5, 6])
x = np.linspace(0, 2*np.pi, 1000) # created a numpy array that goes from 0 to 2pi, and it has 1000 points in the middle. 
x2 = x**2                  
sin_x = np.sin(x) #sinx is calculated at 1000 points

plt.plot(x, np.cos(x), label='cos(x)',
         color='red', linestyle='dashed', )
plt.plot(x, sin_x, label='sin(x)',
         color='blue')
plt.legend()

# %%
x = np.linspace(0, 2*np.pi, 1000) 
x2 = x**2                  
sin_x = np.sin(x) 

plt.plot(x, np.exp(x), label='x^2',
         color='red', linestyle='dashed', )
plt.twinx()
plt.plot(x, sin_x, label='sin(x)',
         color='blue')
plt.legend()

# %%
x = np.linspace(0, 2*np.pi, 1000) 
x2 = x**2                  
sin_x = np.sin(x) 

plt.plot(x, np.exp(x), label='x^2',
         color='red', linestyle='dashed', )
#plt.twinx()
plt.plot(x, sin_x, label='sin(x)',
         color='blue')
plt.legend() 
#twinx allows the 2 plots to have different y axis. Useful when you want to plot different functions with different ranges on the same graph

# %%
#plt.savefig adjust dpi accordingly

# %% [markdown]
# # What to expect in this chapter

# %% [markdown]
# # 1 A simple plot

# %% [markdown]
# ## 1.1 Let’s look at some code.

# %% [markdown]
# ### Things to note

# %%
# Your code here

# %% [markdown]
# ## 1.2 Adding another plot

# %% [markdown]
# ## 1.3 Yet another plot but with error bars

# %% [markdown]
# # 2 Better with NumPy

# %% [markdown]
# ## 2.1 Adding mathematical functions

# %% [markdown]
# ## We need another axis!

# %% [markdown]
# ### Things to note

# %%
# Your code here

# %% [markdown]
# # 3 Saving to disc

# %% [markdown]
# # 4 A real example: Global Warming

# %% [markdown]
# ## 4.1 Plotting data from files

# %% [markdown]
# ## 4.2 Styles

# %% [markdown]
# ### xkcd!

# %%
# Your code here

# %% [markdown]
# ### Resetting styles

# %%
# Your code here
