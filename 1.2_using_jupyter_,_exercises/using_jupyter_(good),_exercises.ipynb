# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Using Jupyter (Good), Exercises</span></div>

# %% [markdown]
# ### Exercise 1

# %%
while True:
    print('*', end='')
# Out:
# **************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************** ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[38], line 2
#       1 while True:
# ----> 2     print('*', end='')
#
# KeyboardInterrupt:

# %% [markdown]
# ### Exercise 2

# %%
print = 'PRINT'

# %%
print('Hello World')
# Out:
# Hello World

# %% [markdown]
# ### Exercise 3

# %%
squares1 = [i**2 for i in range(10)]

# %%
squares2 = list()
for i in range(10):
    squares.append(i**2)

# %%
print(squares1)
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
print(squares2) # Does not give same result?
# Out:
# []

# %%
# %%timeit

squares1 = [i**2 for i in range(10)]
# Out:
# 1.32 μs ± 674 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
# %%timeit

squares2 = list()
for i in range(10):
    squares.append(i**2)
# Out:
# 1.62 μs ± 369 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# Mean/average execution time per loop, standard deviation or variation across each run, 7 runs indicates the number of times %%timeit was run, with 100,000 loops each run
