# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Loops (Good) Exercises</span></div>

# %% [markdown]
# ### Exercise 1

# %%
for number in range(1,10):
    if number % 2 == 0:
        continue

    squares = number**2
    print(f'Odd integer [{number} : {squares}]')
# Out:
# Odd integer [1 : 1]
# Odd integer [3 : 9]
# Odd integer [5 : 25]
# Odd integer [7 : 49]
# Odd integer [9 : 81]

# %%
for number in range(1,10):
    if number % 2 == 0:
        continue

    squares = number**2
    print(squares)
# Out:
# 1
# 9
# 25
# 49
# 81

# %% [markdown]
# ### Exercise 2

# %%
[number**2 for number in range(10) if number % 2 ==1]
# Out:
# [1, 9, 25, 49, 81]

# %% [markdown]
# ### Exercise 3

# %%
# %%timeit -r 10 -n 100 # If not my jupyter notebook keeps crashing
for number in range(1,10):
    if number % 2 == 0:
        continue

    squares = number**2
    print(squares)
# Out:
# 1
# 9
# 25
# 49
# 81
# 1
# 9
# 25
# 49
# 81
# 1
# 9
# 25
# 49
# 81
# 1
# 9
# 25
# 49
# 81
# 1
# 9
# 25
# 49
# 81
# 1
# 9
# 25
# 49
# 81
# 1
# 9
# 25
# 49
# 81
# 1
# 9
# 25
# 49
# 81
# 1
# 9
# 25
# 49
# 81
# 1
# 9
# 25
# 49
# 81
# 1
# 9
# 25
# 49
# 81
# 1
# 9
# 25
# 49
# 81
# 1
# 9
# 25
# 49
# 81
# 1
# 9
# 25
# 49
# 81
# 1
# 9
# 25
# 49
# 81
# 1
# 9
# 25
# 49
# 81
# 1
# 9
# 25
# 49
# 81
# 1
# 9
# 25
# 49
# 81
# 1
# 9
# 25
# 49
# 81
# 1
# 9
# 25
# 49
# 81
# 1
# 9
# 25
# 49
# 81
# 1
# 9
# 25
# 49
# 81
# 1
# 9
# 25
# 49
# 81
# 1
# 9
# 25
# 49
# 81
# 1
# 9
# 25
# 49
# 81
# 1
# 9
# 25
# 49
# 81
# 1
# 9
# 25
# 49
# 81
# 1
# 9
# 25
# 49
# 81
# 1
# 9
# 25
# 49
# 81
# 1
# 9
# 25
# 49
# 81
# 1
# 9
# 25
# 49
# 81
# 1
# 9
# 25
# 49
# 81
# 1
# 9
# 25
# 49
# 81
# 1
# 9
# 25
# 49
# 81
# 1
# 9
# 25
# 49
# 81
# 1
# 9
# 25
# 49
# 81
# 1
# 9
# 25
# 49
# 81
# 1
# 9
# 25
# 49
# 81
# 1
# 9
# 25
# 49
# 81
# 1
# 9
# 25
# 49
# 81
# 1
# 9
# 25
# 49
# 81
# 1
# 9
# 25
# 49
# 81
# 1
# 9
# 25
# 49
# 81
# 1
# 9
# ...

# %%
# %%timeit -r 10 -n 100
[number**2 for number in range(10) if number % 2 ==1]
# Out:
# 1.6 μs ± 427 ns per loop (mean ± std. dev. of 10 runs, 100 loops each)

# %%
# List comprehension is significantly faster

# %% [markdown]
# ### Exercise 4

# %%
initial_quantity = 100
current_quantity = initial_quantity
years = 0

while current_quantity > initial_quantity / 2:
    current_quantity *=0.95
    years+=1

print(years)
# Out:
# 14

# %% [markdown]
# ### Exercise 5

# %%
co2_data = [
    (2000, 369.55), (2001, 371.14), (2002, 373.28), 
    (2003, 375.80), (2004, 377.52), (2005, 379.80), 
    (2006, 381.90), (2007, 383.79), (2008, 385.60), 
    (2009, 387.43), (2010, 389.90), (2011, 391.65), 
    (2012, 393.85), (2013, 396.52), (2014, 398.65),
    (2015, 400.83), (2016, 404.24), (2017, 406.55), 
    (2018, 408.52), (2019, 411.44), (2020, 414.24)
]

# %%
for year, co2_level in co2_data:
    print(year, co2_level)
# Out:
# 2000 369.55
# 2001 371.14
# 2002 373.28
# 2003 375.8
# 2004 377.52
# 2005 379.8
# 2006 381.9
# 2007 383.79
# 2008 385.6
# 2009 387.43
# 2010 389.9
# 2011 391.65
# 2012 393.85
# 2013 396.52
# 2014 398.65
# 2015 400.83
# 2016 404.24
# 2017 406.55
# 2018 408.52
# 2019 411.44
# 2020 414.24

# %%
for index in range(1, len(co2_data)):
    year, co2_level = co2_data[index]
    previous__year, previous_co2_level = co2_data[index - 1]

    change_in_co2 = co2_level - previous_co2_level

    if change_in_co2 >=3:
        print(f'Year:{year} Change:{change_in_co2:.2f}ppm')
        continue
# Out:
# Year:2016 Change:3.41ppm
